# %% [markdown]
# ## Part1

# %%
# !pip install matplotlib

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional Way
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('My Test Graph')
plt.show()

# %%
plt.subplot(1,2,1) #nrow, nclo, figure position
plt.plot(x, y, 'r')
plt.xlabel('Col-1')
plt.ylabel('Row-1')
plt.title('Plot Number-1')

plt.subplot(1,2, 2) #nrow, nclo, figure position
plt.plot(y,x, 'y')
plt.xlabel('Col-2')
plt.ylabel('Row-1')
plt.title('Plot Num-2')
plt.show()

# %%
plt.subplot(1,2,2) #nrow, nclo, figure position
plt.plot(x, y, 'r')
plt.xlabel('Col-1')
plt.ylabel('Row-1')
plt.title('Plot Number-1')

plt.subplot(1,2, 1) #nrow, nclo, figure position
plt.plot(y,x, 'y')
plt.xlabel('Col-2')
plt.ylabel('Row-1')
plt.title('Plot Num-2')
plt.show()

# %% [markdown]
# ## Object oriented method

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # l, B, W, H
axes.plot(x,y)
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-Axis')
axes.set_title('Object oriented Graph')
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.4, 0.3, 0.3, 0.3])
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.3, 0.3, 0.3])
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.2, 0.3, 0.3])
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.3, 0.2, 0.3])
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.3, 0.3, 0.4])
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.6, 0.2, 0.25, 0.15])

axes1.plot(x,y)
axes1.set_title('Large Plot')
axes2.plot(y,x)
axes2.set_title('Smaller plot')
plt.show()

# %% [markdown]
# ## part2

# %%
fig, axes = plt.subplots(figsize= (8,6), nrows=2, ncols=1)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.show()

# %%
fig, axes = plt.subplots(figsize= (8,6), nrows=2, ncols=1)
axes[0].plot(x,y)
axes[0].set_xlabel('X value')
axes[0].set_ylabel('Y Value')
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_xlabel('X value')
axes[1].set_ylabel('Y Value')
axes[1].set_title('Second Plot')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## figsize, dpi

# %%
fig, axes = plt.subplots(figsize=(12,6), nrows=1, ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()
plt.show()

# %%
fig.savefig('my_plot.png')

# %%
fig.savefig('my_plot.png', dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, 'r', label= 'X Squared')
ax.plot(x, x**3,'y', label='X Cubed')
ax.set_title('Learning Legend')

ax.legend(loc=0)

#plt.tight_layout()
plt.show()

# %% [markdown]
# ## part3

# %% [markdown]
# setting color, linewidth, linestyle

# %% [markdown]
# ## Plot Apperarance

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='green')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='#A9F527')  ## RGB Hex code for color
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g')  ## RGB Hex code for color
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='b')  ## RGB Hex code for color
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', linewidth=1)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', linewidth=2)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', linewidth=5)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', linewidth=5, alpha = 0.5)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', linewidth=5, alpha = 0.2)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.2)  
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls=':')  # linestyle
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls='-')  # linestyle
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls='-.')  # linestyle
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls='--')  # linestyle
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls='-', marker='o')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=5, alpha = 0.4, ls='-', marker='*')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.4, ls='-', marker='*')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.4, ls='-', marker='*', markersize=10)  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.4, ls='-', marker='1', markersize=10)  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.8, ls='-', marker='o', markersize=10, markeredgecolor='black')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.8, ls='-', marker='*', markersize=10, markeredgecolor='black')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.8, ls='-', marker='d', markersize=10, markeredgecolor='black')  # linewidth, linestyle, marker
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='g', lw=2, alpha = 0.8, ls='-', marker='d', markersize=10, markeredgecolor='black', markerfacecolor='yellow')  # linewidth, linestyle, marker
plt.show()

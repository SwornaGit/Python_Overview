# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style ('darkgrid')

# %%
df1= pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A']
# Out:
# 2000-01-01    1.339091
# 2000-01-02   -0.774984
# 2000-01-03   -0.921037
# 2000-01-04   -1.738808
# 2000-01-05   -0.905980
#                 ...
# 2002-09-22    1.013897
# 2002-09-23   -0.642659
# 2002-09-24    0.370136
# 2002-09-25    0.183339
# 2002-09-26    0.775133
# Name: A, Length: 1000, dtype: float64

# %%
sns.histplot(x=df1['A'])
plt.show()

# %%
df1['A'].hist(figsize=(12,6),edgecolor='black')
plt.show()

# %%
df1['A'].hist(figsize=(12,6),bins =30,edgecolor='black')
plt.show()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()
plt.show()

# %%
df2.plot.area(figsize=(12,6),alpha=0.4)
plt.show()

# %%
df2.plot.bar(figsize=(12,6),edgecolor='white')
plt.tight_layout()
plt.show()

# %%
df2.plot.bar(stacked=True,figsize=(8,6))
plt.show()

# %%
df1.plot.line(figsize=(8,6),y='B')
plt.show()

# %%
df1.plot.line(figsize=(8,6),y='B',lw ='3') #LINEWIDTH
plt.show()

# %%
df1.plot.scatter(x='A',y='B',c='C',figsize= (12,8),cmap='coolwarm')
plt.show()

# %%
df1.plot.scatter(x='A',y='B',c='C',s= df1['C']*100, figsize= (12,8),cmap='coolwarm')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/matplotlib/collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.plot.box(figsize=(8,6))
plt.show()

# %%
df= pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -1.278838 -0.060686
# 1 -0.387492 -0.443064
# 2 -2.450086  2.111596
# 3 -1.268664  0.782140
# 4  0.850045  0.873504

# %%
df.plot.hexbin(x='a',y='b',figsize=(8,6),gridsize=25,cmap='coolwarm')
plt.show()

# %%
df2['a'].plot.kde()
plt.show()

# %%
df2.plot.kde()
plt.show()

# %%
df2.plot.density()
plt.show()

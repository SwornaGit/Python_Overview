# %% [markdown]
# # Python nampy

# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
1+1
# Out:
# 2

# %%
2*4
# Out:
# 8

# %%
4/2
# Out:
# 2.0

# %%
2**4
# Out:
# 16

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
(2+3)*(5+5)
# Out:
# 50

# %%
var=2

# %%
x=2
y=5

# %%
x+y
# Out:
# 7

# %%
y=10

# %%
x+y
# Out:
# 12

# %%
x=x+x

# %%
x
# Out:
# 4

# %%
x=+ x

# %%
x
# Out:
# 4

# %%
#itarable object . jeta k ami loop er moddhe chalate pari
" my life my role"
# Out:
# ' my life my role'

# %%
"my life my role"[0]
# Out:
# 'm'

# %%
myStr= "my life my role"

# %%
myStr[3]
# Out:
# 'l'

# %%
myStr="we learn python"

# %%
myStr
# Out:
# 'we learn python'

# %%
len(myStr)
# Out:
# 15

# %%
myStr[14]
# Out:
# 'n'

# %%
myStr[-1]
# Out:
# 'n'

# %%
myStr[-3]
# Out:
# 'h'

# %%
myStr[3:8] #index, index position
# Out:
# 'learn'

# %%
s= 'abcdefghk'

# %%
s[0:5]
# Out:
# 'abcde'

# %%
s[0:5:2]
# Out:
# 'ace'

# %%
s[::2] #jumping korbe like 2 ghor por por boshbe
# Out:
# 'acegk'

# %%
s[3::]
# Out:
# 'defghk'

# %%
s[::-1] #inverse the sting
# Out:
# 'khgfedcba'

# %%
num= 29
name='sworna'

# %%
"My name is {} and number is {}" .format(name,num)
# Out:
# 'My name is sworna and number is 29'

# %%
print("My name is {} and number is {}" .format(name,num))
# Out:
# My name is sworna and number is 29

# %%
"My name is {one} and number is {two}" .format(one=name,two=num)
# Out:
# 'My name is sworna and number is 29'

# %%
"My name is {one} and number is {two}" .format(one="sam",two=50)
# Out:
# 'My name is sam and number is 50'

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
[1,2,3,4.5,5,6]
# Out:
# [1, 2, 3, 4.5, 5, 6]

# %%
 [1, 2, 3, 'myname', [2, 3, 4]] #nested list
# Out:
# [1, 2, 3, 'myname', [2, 3, 4]]

# %%
mylist=[1, 2, 3, 'myname', [2, 3, 4]]

# %%
mylist[3]
# Out:
# 'myname'

# %%
mylist[2]= 0

# %%
mylist
# Out:
# [1, 2, 0, 'myname', [2, 3, 4]]

# %%
mylist[0:3]
# Out:
# [1, 2, 0]

# %%
mylist[0:3:2]
# Out:
# [1, 0]

# %%
mylist[::-1]
# Out:
# [[2, 3, 4], 'myname', 0, 2, 1]

# %%
mylist.append(100) #add

# %%
mylist
# Out:
# [1, 2, 0, 'myname', [2, 3, 4], 100]

# %%
mylist.pop() #delete
# Out:
# 100

# %%
mylist.pop(2)
# Out:
# 0

# %%
mylist
# Out:
# [1, 2, 'myname', [2, 3, 4]]

# %%
mylist.remove(1)

# %%
mylist
# Out:
# [2, 'myname', [2, 3, 4]]

# %%
mylist.append(1)

# %%
mylist
# Out:
# [2, 'myname', [2, 3, 4], 1]

# %%
nested_list = [1,2,3,[2,3,["myname"]]]

# %%
nested_list[3]
# Out:
# [2, 3, ['myname']]

# %%
nested_list[3][2][0]
# Out:
# 'myname'

# %%
nested_list[3][2][0][::-1]
# Out:
# 'emanym'

# %% [markdown]
# # PART 2

# %%
{'KEY1':500,'KEY2':'hero', 'key3':50}
# Out:
# {'KEY1': 500, 'KEY2': 'hero', 'key3': 50}

# %%
my_dic = {'KEY1':500,'KEY2':'hero', 'key3':50}

# %%
my_dic['KEY1']
# Out:
# 500

# %%
d = {'k1':{'innerkey':[99,88,77,66]}}

# %%
d['k1']['innerkey'][2]
# Out:
# 77

# %%
t=(1,2,3,3,4)

# %%
t[0]
# Out:
# 1

# %%
type(t)
# Out:
# tuple

# %%
t2=10,

# %%
type(t2)
# Out:
# tuple

# %%
{20,30,40,50,60,70,80,}
# Out:
# {20, 30, 40, 50, 60, 70, 80}

# %%
s={20,30,40,50,60,70,80,}

# %%
s
# Out:
# {20, 30, 40, 50, 60, 70, 80}

# %%
1<2
# Out:
# True

# %%
10==12
# Out:
# False

# %%
if 1<2:
    print('GOOD')
# Out:
# GOOD

# %%
seq= (1,2,3,4,5)

# %%
for num in seq:
    print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x=[1,2,3,4]

# %%
def my_func(name):
    print('Hello')

# %% [markdown]
# ### part4

# %%
def times2(var):
    return var*2

# %%
times2(5)
# Out:
# 10

# %%
seq= [1,2,3,4,5]

# %%
map(times2,seq)

# %%
list(map(times2,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
xyz=[]
for x in seq:
    xyz.append(times2(x))
print (xyz)
# Out:
# [2, 4, 6, 8, 10]

# %%
[num**2 for num in seq] #list comprihension
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# ### lambda function

# %%
def times2(var):
    return var*2

# %%
def times2(var):return var*2

# %%
times2(15)
# Out:
# 30

# %%
lambda var:var*2
# Out:
# <function __main__.<lambda>(var)>

# %%
times3= lambda var:var*2

# %%
list(map(times3,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(lambda x:x*2,seq))
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### Filter function

# %%
lambda num:num%2==0
# Out:
# <function __main__.<lambda>(num)>

# %%
list(map(lambda num:num%2==0, seq))
# Out:
# [False, True, False, True, False]

# %%
filter(lambda num:num%2==0,seq)

# %%
list(filter(lambda num:num%2==0,seq))
# Out:
# [2, 4]

# %% [markdown]
# ### methods

# %%
s= "Hello my name is sam"

# %%
s.lower ()
# Out:
# 'hello my name is sam'

# %%
s.upper()
# Out:
# 'HELLO MY NAME IS SAM'

# %%
s.capitalize()
# Out:
# 'Hello my name is sam'

# %%
s.split()
# Out:
# ['Hello', 'my', 'name', 'is', 'sam']

# %%
tweet= "Go Sports ! # Sports"

# %%
tweet.split('#')
# Out:
# ['Go Sports ! ', ' Sports']

# %%
tweet.split('#')[1]
# Out:
# ' Sports'

# %%
d ={ 'k1':10, 'k2':20 }

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2'])

# %%
d.items()
# Out:
# dict_items([('k1', 10), ('k2', 20)])

# %%
d.values()
# Out:
# dict_values([10, 20])

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
4 in [1,2,3,4]
# Out:
# True

# %%
[2,3] in [1,2,3,4]
# Out:
# False

# %%
[2,3] in [1,[2,3],4]
# Out:
# True

# %%
x=[(10,20),(30,40),(50,60)]

# %%
x[2]
# Out:
# (50, 60)

# %%
x[2][1]
# Out:
# 60

# %%
for i in x:
    print(i)
# Out:
# (10, 20)
# (30, 40)
# (50, 60)

# %%
for i,j in x:
    print (i)
    print(j)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
for i,j in x:
    print (j)
# Out:
# 20
# 40
# 60

# %%
for i,j in x:
     print(i)
# Out:
# 10
# 30
# 50
